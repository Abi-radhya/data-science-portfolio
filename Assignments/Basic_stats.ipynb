# %%
import pandas as pd
df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
num_col=df.select_dtypes(['number'])
num_col
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
num_col.mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
num_col.mode().iloc[0]
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
num_col.median()
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
num_col.std()
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
# The dataset shows variability across key metrics:
# Volume: The average number of units sold is 5, but the most common is 3, indicating fluctuating sales.
# Avg Price: The average price is ₹10,453, but the median is ₹1,450, suggesting a mix of high and low prices.
# Total Sales Value: The average total sales value is ₹33,813, but the median is much lower at ₹5,700.
# Discount Rate: The average discount is 15.16%, with most discounts being smaller (mode of 5.01%).
# Discount Amount: The average discount is ₹3,347, but smaller discounts are more frequent.
# Net Sales Value: The average net sales value is ₹30,466, with high-value transactions influencing the average.
# Overall, there’s significant variation in the sales volumes, prices, and discounts across transactions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("sales_data_with_discounts.csv")  
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

sns.histplot(data['Volume'], kde=True)
plt.title('Distribution of Volume', fontsize=20, color="hotpink")
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data['Avg Price'], kde=True)
plt.title('Distribution of Avg Price', fontsize=20, color="yellow")
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data['Total Sales Value'], kde=True)
plt.title('Distribution of Total Sales Value', fontsize=20, color="orange")
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data['Discount Rate (%)'], kde=True)
plt.title('Distribution of Discount Rate', fontsize=20, color="red")
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data['Discount Amount'], kde=True)
plt.title('Distribution of Discount Amount', fontsize=20, color="green")
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data['Net Sales Value'], kde=True)
plt.title('Distribution of Net Sales Value', fontsize=20, color="purple")
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Histograms for the numerical columns show how values are distributed. 
# For example, some columns like Avg Price and Total Sales Value are right-skewed, indicating a few very high values. 
# Columns like Volume are more normally distributed. This helps identify skewness and potential outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_style("whitegrid")

# Boxplot for Volume
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Volume'], color='skyblue')
plt.title('Boxplot of Volume', fontsize=12)
plt.xlabel('Volume', fontsize=10)
plt.show()

# Boxplot for Avg Price
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Avg Price'], color='lightgreen')
plt.title('Boxplot of Avg Price', fontsize=12)
plt.xlabel('Avg Price', fontsize=10)
plt.show()

# Boxplot for Total Sales Value
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Total Sales Value'], color='salmon')
plt.title('Boxplot of Total Sales Value', fontsize=12)
plt.xlabel('Total Sales Value', fontsize=10)
plt.show()

# Boxplot for Discount Rate 
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Discount Rate (%)'], color='plum')
plt.title('Boxplot of Discount Rate', fontsize=12)
plt.xlabel('Discount Rate', fontsize=10)
plt.show()

# Boxplot for Discount Amount
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Discount Amount'], color='orange')
plt.title('Boxplot of Discount Amount', fontsize=12)
plt.xlabel('Discount Amount', fontsize=10)
plt.show()

# Boxplot for Net Sales Value
plt.figure(figsize=(8, 3))
sns.boxplot(x=data['Net Sales Value'], color='lightcoral')
plt.title('Boxplot of Net Sales Value', fontsize=12)
plt.xlabel('Net Sales Value', fontsize=10)
plt.show()

# %%
# Boxplots revealed several outliers in columns like Avg Price, Discount Amount, and Net Sales Value. 
# These extreme values affect the mean and suggest that some transactions are significantly different from the rest. 
# The interquartile range (IQR) gives a good sense of the spread of typical values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

plt.figure(figsize=(7, 4))
sns.countplot(x=data['Day'], palette='Set2', edgecolor='black')
plt.title('Sales Distribution by Day', fontsize=14)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Entries', fontsize=12)
plt.tight_layout()
plt.show()


plt.figure(figsize=(7, 4))
sns.countplot(x=data['BU'], palette='Pastel1', edgecolor='black')
plt.title('Product Category (BU) Distribution', fontsize=14)
plt.xlabel('Business Unit', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.tight_layout()
plt.show()


plt.figure(figsize=(8, 4))
sns.countplot(x=data['Brand'], palette='Pastel2', edgecolor='black')
plt.title('Brand Distribution', fontsize=14)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abhinaya\AppData\Local\Temp\ipykernel_14216\1521089939.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Day'], palette='Set2', edgecolor='black')
# C:\Users\Abhinaya\AppData\Local\Temp\ipykernel_14216\1521089939.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['BU'], palette='Pastel1', edgecolor='black')
# C:\Users\Abhinaya\AppData\Local\Temp\ipykernel_14216\1521089939.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Brand'], palette='Pastel2', edgecolor='black')

# %%
# Day:
# The dataset seems to only contain "Thursday" as the Day, which might indicate data collection was done weekly or only on Thursdays.
#(Not enough variety to analyze trends over the week.)
# BU:
# Two categories: Mobiles and Lifestyle.
# Mobiles seem to dominate the data (visually higher count).
# Business insights: The company may be more focused on electronics compared to lifestyle items.
# Brand:
# Brands like RealU and YouM (for Mobiles), and Jeera and Viva (for Lifestyle) are repeated.
# Brand-wise distribution can help the marketing team understand which brands are most common in sales.

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
# Standardization, also known as z-score normalization, is a technique used to bring all numerical variables onto a common scale 
# without distorting differences in the ranges of values. 
# It involves transforming the data so that it has a mean of 0 and a standard deviation of 1. 
# This is done by subtracting the mean of a column from each value and then dividing the result by the standard deviation of that column. 
# The formula used is: z = (x - μ) / σ, where x is the original value, μ is the mean, and σ is the standard deviation. 
# Standardizing data is especially useful when comparing features with different units or scales, 
# and it helps improve the performance and accuracy of many analytical and machine learning models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

for col in num_cols:
    plt.figure(figsize=(5, 3))
    sns.histplot(data[col], kde=True, color='skyblue')
    plt.title(f'{col} - Before Standardization')
    plt.tight_layout()
    plt.show()

for col in num_cols:
    mean = data[col].mean()
    std = data[col].std()
    data[col + '_std'] = (data[col] - mean) / std

for col in num_cols:
    plt.figure(figsize=(5, 3))
    sns.histplot(data[col + '_std'], kde=True, color='lightgreen')
    plt.title(f'{col} - After Standardization')
    plt.tight_layout()
    plt.show()

# %%
# Most machine learning algorithms cannot work directly with categorical text data like "Male", "Female", "Red", "Blue", etc. 
# These need to be converted into a numerical format. One common method is One-Hot Encoding, which creates binary (0 or 1) columns for each category.

# %%
import pandas as pd
df=pd.read_csv("sales_data_with_discounts.csv")
categorical_cols = ['BU', 'Brand', 'City']  
data_encoded = pd.get_dummies(data, columns=categorical_cols)
print(data_encoded.head())
# Out:
#          Date       Day  SKU  Volume       Model  Avg Price  \
# 0  01-04-2021  Thursday  M01      15       RU-10      12100
# 1  01-04-2021  Thursday  M02      10   RU-9 Plus      10100
# 2  01-04-2021  Thursday  M03       7       YM-99      16100
# 3  01-04-2021  Thursday  M04       6  YM-99 Plus      20100
# 4  01-04-2021  Thursday  M05       3      YM-98        8100
#
#    Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# 0             181500          11.654820     21153.498820    160346.501180
# 1             101000          11.560498     11676.102961     89323.897039
# 2             112700           9.456886     10657.910157    102042.089843
# 3             120600           6.935385      8364.074702    112235.925298
# 4              24300          17.995663      4372.946230     19927.053770
#
#    ...  Brand_Babaji  Brand_Gear  Brand_Jeera  Brand_Orange  Brand_RealU  \
# 0  ...         False       False        False         False         True
# ...

# %%
# Descriptive analytics and visualizations revealed that "Mobiles" and "Lifestyle" were the most frequent product categories,
# with brands like "YouM" and "RealU" being prominent. These insights help identify key trends in the data.
# Data preprocessing steps like standardization and one-hot encoding are crucial. 
# Standardization scales numeric data for consistency, while one-hot encoding converts categories into True/False columns, 
# making the data suitable for machine learning models.
